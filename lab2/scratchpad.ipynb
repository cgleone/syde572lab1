# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

data1 = loadmat('lab2_1.mat')
data2 = loadmat('lab2_2.mat')
data3 = loadmat('lab2_3.mat')

a = data1['a']
b = data1['b']

# %%
a = data1['a']
b = data1['b']

# %%
plt.hist(a.flatten(), bins=20)
plt.xlim(0, 10)
plt.show()

# %% [markdown]
# # Q3 Sequential Classifier

# %% [markdown]
# Perceptron approach
# 1. Set initial guess for weight a_0 and let k = 0
# 2. Based on a_k, construct classifier and determine set of mis-classified samples Y(a). If there are no misclassified samples, stop here, since we hava arrived at our solution
# 3. Compute a scalar mutiple of the k'th misclassified sample, rho_k y^k
# 4. Determine a_k+1 as a_k+1 = a_k + rho_k y^k
# 5. Go to step 2

# %%
a = data3['a']
b = data3['b']

plt.scatter(a[:, 0], a[:, 1], label='a')
plt.scatter(b[:, 0], b[:, 1], label='b')
plt.legend()
plt.show()
